# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials


client_id = 'ac249f8bfc274671a2b90cd8fcc4c4ca'
secret_id = 'fe6dae5f957f4a47bc6657113af3e236'
credentials = SpotifyClientCredentials(client_id=client_id,
                                       client_secret=secret_id)
sp = spotipy.Spotify(client_credentials_manager=credentials)

sp.track('1OOOjuRfvzeTIC0t0KJ4ln')
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3kY4OxlGQbaALboEgvgu2W'},
#     'href': 'https://api.spotify.com/v1/artists/3kY4OxlGQbaALboEgvgu2W',
#     'id': '3kY4OxlGQbaALboEgvgu2W',
#     'name': 'President Franklin Delano Roosevelt',
#     'type': 'artist',
#     'uri': 'spotify:artist:3kY4OxlGQbaALboEgvgu2W'}],
#   'available_markets': ['AD',
#    'AE',
#    'AL',
#    'AR',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'BY',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'KZ',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MK',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'SA',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'UA',
#    'US',
#    'UY',
#    'VN',
#    'XK',
#    'ZA'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/7yrfmjiuvH4dWJgof9lPFH'},
#   'href': 'https://api.spotify.com/v1/albums/7yrfmjiuvH4dWJgof9lPFH',
#   'id': '7yrfmjiuvH4dWJgof9lPFH',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273c026a552fa7ffb1e747ce10b',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02c026a552fa7ffb1e747ce10b',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851c026a552fa7ffb1e747ce10b',
#     'width': 64}],
#   'name': 'The Ultimate Franklin Delano Roosevelt Collection',
#   'release_date': '1950',
#   'release_date_precision': 'year',
#   'total_tracks': 40,
#   'type': 'album',
#   'uri': 'spotify:album:7yrfmjiuvH4dWJgof9lPFH'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3kY4OxlGQbaALboEgvgu2W'},
#    'href': 'https://api.spotify.com/v1/artists/3kY4OxlGQbaALboEgvgu2W',
#    'id': '3kY4OxlGQbaALboEgvgu2W',
#    'name': 'President Franklin Delano Roosevelt',
#    'type': 'artist',
#    'uri': 'spotify:artist:3kY4OxlGQbaALboEgvgu2W'}],
#  'available_markets': ['AD',
#   'AE',
#   'AL',
#   'AR',
#   'AT',
#   'AU',
#   'BA',
#   'BE',
#   'BG',
#   'BH',
#   'BO',
#   'BR',
#   'BY',
#   'CA',
#   'CH',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DE',
#   'DK',
#   'DO',
#   'DZ',
#   'EC',
#   'EE',
#   'EG',
#   'ES',
#   'FI',
#   'FR',
#   'GB',
#   'GR',
#   'GT',
#   'HK',
#   'HN',
#   'HR',
#   'HU',
#   'ID',
#   'IE',
#   'IL',
#   'IN',
#   'IS',
#   'IT',
#   'JO',
#   'JP',
#   'KW',
#   'KZ',
#   'LB',
#   'LI',
#   'LT',
#   'LU',
#   'LV',
#   'MA',
#   'MC',
#   'MD',
#   'ME',
#   'MK',
#   'MT',
#   'MX',
#   'MY',
#   'NI',
#   'NL',
#   'NO',
#   'NZ',
#   'OM',
#   'PA',
#   'PE',
#   'PH',
#   'PL',
#   'PS',
#   'PT',
#   'PY',
#   'QA',
#   'RO',
#   'RS',
#   'RU',
#   'SA',
#   'SE',
#   'SG',
#   'SI',
#   'SK',
#   'SV',
#   'TH',
#   'TN',
#   'TR',
#   'TW',
#   'UA',
#   'US',
#   'UY',
#   'VN',
#   'XK',
#   'ZA'],
#  'disc_number': 1,
#  'duration_ms': 1601619,
#  'explicit': False,
#  'external_ids': {'isrc': 'USJ3V1291592'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/1OOOjuRfvzeTIC0t0KJ4ln'},
#  'href': 'https://api.spotify.com/v1/tracks/1OOOjuRfvzeTIC0t0KJ4ln',
#  'id': '1OOOjuRfvzeTIC0t0KJ4ln',
#  'is_local': False,
#  'name': 'Fireside Chat #6 - On Government and Capitalism (September 30, 1934)',
#  'popularity': 0,
#  'preview_url': None,
#  'track_number': 4,
#  'type': 'track',
#  'uri': 'spotify:track:1OOOjuRfvzeTIC0t0KJ4ln'}
